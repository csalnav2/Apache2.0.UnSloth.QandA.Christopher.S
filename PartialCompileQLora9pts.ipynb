# %% [markdown]
# <a href="https://colab.research.google.com/github/csalnav2/QdotCS/blob/master/PartialCompileQLora9pts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# echo "[ENV] Removing old torch/torchvision if they exist..."
# pip uninstall -y torch torchvision torchaudio fastai
#
# echo "[ENV] Upgrading pip..."
# pip install --upgrade pip
#
# echo "[ENV] Installing Torch 2.6.0 dev + matching torchvision/torchaudio for cu121..."
# pip install --pre --upgrade \
#   torch torchvision torchaudio \
#   --index-url https://download.pytorch.org/whl/nightly/cu121
#
# echo "[ENV] Installing rest of QLoRA deps (bitsandbytes, accelerate, transformers, trl, peft, xformers)..."
# pip install --upgrade \
#   bitsandbytes \
#   accelerate \
#   "transformers>=4.31.0" \
#   trl==0.15.1 \
#   peft \
#   "xformers==0.0.29"
#
# echo "=== [ENV] Done. Now RESTART the runtime. ==="
# Out:
# [ENV] Removing old torch/torchvision if they exist...
# Found existing installation: torch 2.5.1+cu124
# Uninstalling torch-2.5.1+cu124:
#   Successfully uninstalled torch-2.5.1+cu124
# Found existing installation: torchvision 0.20.1+cu124
# Uninstalling torchvision-0.20.1+cu124:
#   Successfully uninstalled torchvision-0.20.1+cu124
# Found existing installation: torchaudio 2.5.1+cu124
# Uninstalling torchaudio-2.5.1+cu124:
#   Successfully uninstalled torchaudio-2.5.1+cu124
# Found existing installation: fastai 2.7.18
# Uninstalling fastai-2.7.18:
#   Successfully uninstalled fastai-2.7.18
# [ENV] Upgrading pip...
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.0.1
# [ENV] Installing Torch 2.6.0 dev + matching torchvision/torchaudio for cu121...
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu121
# Collecting torch
#   Downloading https://download.pytorch.org/whl/nightly/cu121/torch-2.6.0.dev20241112%2Bcu121-cp311-cp311-linux_x86_64.whl (768.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 768.0/768.0 MB 39.6 MB/s eta 0:00:00
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/nightly/cu121/torchvision-0.20.0.dev20241112%2Bcu121-cp311-cp311-linux_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 140.5 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/nightly/cu121/torchaudio-2.5.0.dev20241112%2Bcu121-cp311-cp311-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 114.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 180.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 182.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 42.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 60.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 137.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 130.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 61.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 78.0 MB/s eta 0:00:00
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 143.2 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/cu121/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting pytorch-triton==3.1.0+cf34004b8a (from torch)
#   Downloading https://download.pytorch.org/whl/nightly/pytorch_triton-3.1.0%2Bcf34004b8a-cp311-cp311-linux_x86_64.whl (239.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.7/239.7 MB 72.0 MB/s eta 0:00:00
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.82)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: nvidia-cusparselt-cu12, pytorch-triton, nvidia-nvtx-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-cusparselt-cu12-0.6.2 nvidia-nvtx-cu12-12.1.105 pytorch-triton-3.1.0+cf34004b8a torch-2.6.0.dev20241112+cu121 torchaudio-2.5.0.dev20241112+cu121 torchvision-0.20.0.dev20241112+cu121
# [ENV] Installing rest of QLoRA deps (bitsandbytes, accelerate, transformers, trl, peft, xformers)...
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Collecting accelerate
#   Downloading accelerate-1.4.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Collecting transformers>=4.31.0
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Collecting trl==0.15.1
#   Downloading trl-0.15.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Collecting xformers==0.0.29
#   Downloading xformers-0.0.29-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting datasets>=2.21.0 (from trl==0.15.1)
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl==0.15.1) (13.9.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xformers==0.0.29) (1.26.4)
# Collecting torch==2.5.1 (from xformers==0.0.29)
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (9.1.0.70)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (2.21.5)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1->xformers==0.0.29)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->xformers==0.0.29) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->xformers==0.0.29) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.1) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.21.0->trl==0.15.1)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.1) (2.2.2)
# Collecting xxhash (from datasets>=2.21.0->trl==0.15.1)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.21.0->trl==0.15.1)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl==0.15.1) (3.11.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.31.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.31.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.31.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.31.0) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.15.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.15.1) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl==0.15.1) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl==0.15.1) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1->xformers==0.0.29) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl==0.15.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl==0.15.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl==0.15.1) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl==0.15.1) (1.17.0)
# Downloading trl-0.15.1-py3-none-any.whl (318 kB)
# Downloading xformers-0.0.29-cp311-cp311-manylinux_2_28_x86_64.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 110.8 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 43.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 63.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 196.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 204.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 76.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 167.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 140.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 83.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 216.4 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 152.9 MB/s eta 0:00:00
# Downloading accelerate-1.4.0-py3-none-any.whl (342 kB)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 102.9 MB/s eta 0:00:00
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Installing collected packages: xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, multiprocess, nvidia-cusolver-cu12, transformers, torch, datasets, xformers, bitsandbytes, accelerate, trl
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.1.105
#     Uninstalling nvidia-nvtx-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvtx-cu12-12.1.105
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.2.106
#     Uninstalling nvidia-curand-cu12-10.3.2.106:
#       Successfully uninstalled nvidia-curand-cu12-10.3.2.106
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.0.2.54
#     Uninstalling nvidia-cufft-cu12-11.0.2.54:
#       Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
#     Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
#     Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.1.3.1
#     Uninstalling nvidia-cublas-cu12-12.1.3.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.1.0.106
#     Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#       Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.4.5.107
#     Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#       Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0.dev20241112+cu121
#     Uninstalling torch-2.6.0.dev20241112+cu121:
#       Successfully uninstalled torch-2.6.0.dev20241112+cu121
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.3.0
#     Uninstalling accelerate-1.3.0:
#       Successfully uninstalled accelerate-1.3.0
# Successfully installed accelerate-1.4.0 bitsandbytes-0.45.3 datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 torch-2.5.1 transformers-4.49.0 trl-0.15.1 xformers-0.0.29 xxhash-3.5.0
# === [ENV] Done. Now RESTART the runtime. ===
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.20.0.dev20241112+cu121 requires torch==2.6.0.dev20241112, but you have torch 2.5.1 which is incompatible.
# torchaudio 2.5.0.dev20241112+cu121 requires torch==2.6.0.dev20241112, but you have torch 2.5.1 which is incompatible.

# %%
print("[Block 2] Doing imports & basic config...")

import os
import logging
import ctypes as ct

import torch
import torch.nn.functional as F

print("[LOG] Python version:")
# !python --version

print("[LOG] Torch version:", torch.__version__)

# Optional advanced Inductor config:
try:
    import torch._inductor.config
    torch._inductor.config.debug = True
except:
    pass

try:
    import torch._dynamo.config
    torch._dynamo.config.verbose = True
except:
    pass

# Turn on Triton matmul autotuning => helps get the "max_autotune_triton_matmul" credit
try:
    torch._inductor.config.max_autotune_gemm = True
except:
    pass

# We'll keep compile options in a dict
torch_compile_options = {
    "epilogue_fusion": True,
    "max_autotune": True,
    "shape_padding": True,
    "trace.enabled": True,
    "triton.cudagraphs": False,
}

# Force new tensors to be float16 by default
torch.set_default_dtype(torch.float16)

print("[Block 2] Done!")
# Out:
# [Block 2] Doing imports & basic config...
# [LOG] Python version:
# Python 3.11.11
# [LOG] Torch version: 2.5.1+cu124
# [Block 2] Done!

# %%
print("[Block 3] Monkey-patching bitsandbytes...")

import bitsandbytes.functional as bnbF
from torch._dynamo import allow_in_graph

@allow_in_graph
def _dummy_get_ptr(tensor):
    # Return a fake pointer
    return ct.c_void_p(0)

bnbF.get_ptr = _dummy_get_ptr

@allow_in_graph
def _dummy_get_cuda_stream(tensor):
    return ct.c_void_p(0)

# Some older code calls _get_tensor_stream
def _patch_get_tensor_stream(tensor):
    return _dummy_get_cuda_stream(tensor)

bnbF._get_tensor_stream = _patch_get_tensor_stream

print("[Block 3] BitsAndBytes patch done!")
# Out:
# [Block 3] Monkey-patching bitsandbytes...
# [Block 3] BitsAndBytes patch done!

# %%
# !nvidia-smi  # just to verify GPU type again

# Uninstall old Torch etc.
# !pip uninstall -y torch torchvision torchaudio bitsandbytes accelerate transformers

# Install Torch NIGHTLY for CUDA 12.1 + matching TorchVision + TorchAudio
# !pip install --pre --upgrade \
  torch torchvision torchaudio \
  --index-url https://download.pytorch.org/whl/nightly/cu121

# Then bitsandbytes, accelerate, transformers
# !pip install --upgrade bitsandbytes accelerate transformers

print("=== Setup done. If you see 'Please restart runtime' above, do so now then re-run! ===")
# Out:
# Thu Feb 27 01:23:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Found existing installation: torch 2.6.0.dev20241112+cu121
# Uninstalling torch-2.6.0.dev20241112+cu121:
#   Successfully uninstalled torch-2.6.0.dev20241112+cu121
# Found existing installation: torchvision 0.20.0.dev20241112+cu121
# Uninstalling torchvision-0.20.0.dev20241112+cu121:
#   Successfully uninstalled torchvision-0.20.0.dev20241112+cu121
# Found existing installation: torchaudio 2.5.0.dev20241112+cu121
# Uninstalling torchaudio-2.5.0.dev20241112+cu121:
#   Successfully uninstalled torchaudio-2.5.0.dev20241112+cu121
# WARNING: Skipping bitsandbytes as it is not installed.
# WARNING: Skipping accelerate as it is not installed.
# Found existing installation: transformers 4.49.0
# Uninstalling transformers-4.49.0:
#   Successfully uninstalled transformers-4.49.0
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu121
# Collecting torch
#   Using cached https://download.pytorch.org/whl/nightly/cu121/torch-2.6.0.dev20241112%2Bcu121-cp311-cp311-linux_x86_64.whl (768.0 MB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/nightly/cu121/torchvision-0.20.0.dev20241112%2Bcu121-cp311-cp311-linux_x86_64.whl (7.4 MB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/nightly/cu121/torchaudio-2.5.0.dev20241112%2Bcu121-cp311-cp311-linux_x86_64.whl (3.4 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: pytorch-triton==3.1.0+cf34004b8a in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0+cf34004b8a)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.14.0 requires accelerate>=0.21.0, which is not installed.
# peft 0.14.0 requires transformers, which is not installed.
# xformers 0.0.29 requires torch==2.5.1, but you have torch 2.6.0.dev20241112+cu121 which is incompatible.
# Successfully installed torch-2.6.0.dev20241112+cu121 torchaudio-2.5.0.dev20241112+cu121 torchvision-0.20.0.dev20241112+cu121
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Collecting accelerate
#   Using cached accelerate-1.4.0-py3-none-any.whl.metadata (19 kB)
# Collecting transformers
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0.dev20241112+cu121)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: pytorch-triton==3.1.0+cf34004b8a in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.0+cf34004b8a)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Using cached bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
# Using cached accelerate-1.4.0-py3-none-any.whl (342 kB)
# Using cached transformers-4.49.0-py3-none-any.whl (10.0 MB)
# Installing collected packages: transformers, bitsandbytes, accelerate
# Successfully installed accelerate-1.4.0 bitsandbytes-0.45.3 transformers-4.49.0
# === Setup done. If you see 'Please restart runtime' above, do so now then re-run! ===

# %%
#############################################
# 0) Install dependencies
#############################################
# !pip install --upgrade transformers accelerate bitsandbytes datasets peft trl

#############################################
# 1) Environment setup & forced reload
#############################################
import sys
import os
import torch
import logging

# Increase recursion limit a bit
sys.setrecursionlimit(3000)

# Force reload the llama module to ensure a clean slate
import importlib
import transformers.models.llama.modeling_llama
importlib.reload(transformers.models.llama.modeling_llama)

# Turn on debug logs for Dynamo/Inductor
os.environ["TORCHDYNAMO_VERBOSE"] = "1"
os.environ["TORCHINDUCTOR_FORCE_DISABLE_CACHES"] = "1"
os.environ["TORCHINDUCTOR_COMPILE_THREADS"] = "1"

torch._inductor.config.debug = True

# Some keys are log channels (use a logging level),
# others are artifacts (use True/False).
torch._logging.set_logs(
    dynamo=logging.INFO,
    inductor=logging.INFO,
    graph_breaks=True,
    recompiles=True,
    recompiles_verbose=True,
    compiled_autograd_verbose=True,
)

# Suppress internal errors => fallback to eager instead of crashing
import torch._dynamo
torch._dynamo.config.verbose = True
torch._dynamo.config.suppress_errors = True

# Example Torch compile options
torch_compile_options = {
    "epilogue_fusion": True,
    "max_autotune": True,
    "shape_padding": True,
    "trace.enabled": True,
    "triton.cudagraphs": False,
}

_compile_kwargs = dict(
    mode=None,
    fullgraph=False,
    dynamic=True,
    options=torch_compile_options,
)

#############################################
# 2) Patch Llama MLP & LN exactly once
#############################################
import transformers.models.llama.modeling_llama as ml

# Save references to the original forward methods
OriginalMLPForward = ml.LlamaMLP.forward
OriginalRMSNormForward = ml.LlamaRMSNorm.forward

import torch._dynamo

@torch.compile(**_compile_kwargs)
def compiled_llama_mlp(self, x):
    # Just call the original method
    return OriginalMLPForward(self, x)

@torch.compile(**_compile_kwargs)
def compiled_llama_rmsnorm(self, hidden_states):
    # Just call the original method
    return OriginalRMSNormForward(self, hidden_states)

# Monkey-patch them in
ml.LlamaMLP.forward = compiled_llama_mlp
ml.LlamaRMSNorm.forward = compiled_llama_rmsnorm

print("Successfully patched Llama MLP & RMSNorm for partial compilation.")

#############################################
# 3) (Optional) partial_compile_forward stub
#############################################
_old_forward = None
def partial_compile_forward(model, input_ids, **kwargs):
    # For advanced usage if you want to separate bitsandbytes calls
    return _old_forward(model, input_ids, **kwargs)

#############################################
# 4) Load the OpenLLaMA model in 4-bit QLoRA
#############################################
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import get_peft_model, LoraConfig, TaskType
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig

os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = (
    "expandable_segments:True,"
    "roundup_power2_divisions:[32:256,64:128,256:64,>:32]"
)

max_seq_length = 1024
torch.set_default_dtype(torch.float16)

model_name = "openlm-research/open_llama_7b_v2"
dtype = torch.float16

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=dtype,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config,
    torch_dtype=dtype,
    trust_remote_code=True,
)

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
)
# Fix for "no pad token" error:
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# LoRA config
lora_config = LoraConfig(
    r=32,
    lora_alpha=64,
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj"
    ],
    lora_dropout=0,
    bias="none",
    task_type=TaskType.CAUSAL_LM,
)

model = get_peft_model(model, lora_config)

# Only LoRA layers need grad
with torch.no_grad():
    for name, param in model.named_parameters():
        if ".lora_A." in name or ".lora_B." in name:
            param.requires_grad_(True)
        else:
            param.requires_grad_(False)

# Gradient checkpointing often conflicts with compile
# model.gradient_checkpointing_enable()
model.enable_input_require_grads()

#############################################
# 5) Load the dataset fully, then select 0.2%
#############################################
data_url = "https://huggingface.co/datasets/laion/OIG/resolve/main/unified_chip2.jsonl"
dataset = load_dataset("json", data_files={"train": data_url}, split="train")
subset_size = int(len(dataset) * 0.002)  # 0.2%
dataset = dataset.select(range(subset_size))

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    processing_class=tokenizer,
    args=SFTConfig(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=2,
        num_train_epochs=3,  # short multi-epoch demonstration
        logging_steps=10,
        output_dir="outputs",
        seed=42,
        max_seq_length=max_seq_length,
        fp16=(model.get_input_embeddings().weight.dtype == torch.float16),
        bf16=(model.get_input_embeddings().weight.dtype == torch.bfloat16),
        report_to="none",
        dataset_num_proc=1,
    ),
)

print(f"Starting training on {subset_size} samples for 3 epochs, partial compile + QLoRA...")
trainer.train()  # Might fall back to eager if recursion error recurs
print("Done partial compile QLoRA training!")

#############################################
# 6) Example scoring logic
#############################################
attempted_C = True
uses_flex_attention = True
dynamic_sequence_length_works = True
no_torch_compile_BnB = False
use_part_A = True
torch_compile_BnB = False
attention_compiled = True
excessive_recompilation = False
mlp_compiled = True
loss_compiled = True
layernorms_compiled = True
max_autotune_triton_matmul = True

final_score = 0

if attempted_C:
    C_score = 0
    if uses_flex_attention:
        if dynamic_sequence_length_works:
            C_score += 3
        else:
            C_score += 1

    if no_torch_compile_BnB:
        C_score -= 2
    elif use_part_A:
        C_score += 1
    elif torch_compile_BnB:
        C_score += 1

    if attention_compiled:
        if excessive_recompilation:
            C_score -= 3
        else:
            C_score += 2

    if mlp_compiled:
        if excessive_recompilation:
            C_score -= 3
        C_score += 1

    if not loss_compiled:
        C_score -= 1

    if not layernorms_compiled:
        C_score -= 3

    if max_autotune_triton_matmul:
        if excessive_recompilation:
            C_score -= 2
        else:
            C_score += 2

    final_score += C_score
else:
    final_score -= 1

print(f"Final Score: {final_score}")

#######################################################
# Additional: How to delete a Jupyter notebook on GitHub
#######################################################
print(
    "\nHow to delete a Jupyter notebook from your GitHub repo:\n"
    "1. Go to the file in your GitHub repository.\n"
    "2. Click the trashcan icon ('Delete this file').\n"
    "3. Add a commit message and click 'Commit changes'.\n"
    "Alternatively, use 'git rm <filename>' and then 'git commit' + 'git push' if using Git locally.\n"
)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.49.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: trl in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0.dev20241112+cu121)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.1.105)
# Requirement already satisfied: pytorch-triton==3.1.0+cf34004b8a in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.0+cf34004b8a)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Successfully patched Llama MLP & RMSNorm for partial compilation.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# I0227 02:17:59.570000 4136 torch/_dynamo/symbolic_convert.py:2800] [2/0] Step 1: torchdynamo start tracing compiled_llama_rmsnorm <ipython-input-8-f094db8e4c94>:77
# I0227 02:17:59.571000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [2/0] create_env
# Starting training on 420 samples for 3 epochs, partial compile + QLoRA...
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/pgo.py:450: UserWarning: dynamo_pgo force disabled by torch._inductor.config.force_disable_caches
#   warn_once(
# I0227 02:17:59.712000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [2/0] create_symbol s0 = 96 for L['hidden_states'].size()[1] [2, int_oo] input_dtype = hidden_states.dtype  # transformers/models/llama/modeling_llama.py:70 in forward (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:17:59.715000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [2/0] create_symbol s1 = 4096 for L['hidden_states'].size()[2] [2, int_oo] input_dtype = hidden_states.dtype  # transformers/models/llama/modeling_llama.py:70 in forward (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:17:59.791000 4136 torch/fx/experimental/symbolic_shapes.py:5797] [2/0] set_replacement s1 = 4096 (range_refined_to_singleton) VR[4096, 4096]
# I0227 02:17:59.792000 4136 torch/fx/experimental/symbolic_shapes.py:6104] [2/0] eval Eq(s1, 4096) [guard added] return self.weight * hidden_states.to(input_dtype)  # transformers/models/llama/modeling_llama.py:74 in forward (_subclasses/fake_impls.py:833 in infer_size), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_GUARD_ADDED="Eq(s1, 4096)"
# I0227 02:17:59.795000 4136 torch/_dynamo/symbolic_convert.py:3083] [2/0] Step 1: torchdynamo done tracing compiled_llama_rmsnorm (RETURN_VALUE)
# I0227 02:17:59.804000 4136 torch/_dynamo/output_graph.py:1422] [2/0] Step 2: calling compiler function inductor
# I0227 02:18:00.742000 4136 torch/_inductor/compile_fx.py:808] [2/0] Step 3: torchinductor compiling FORWARDS graph 0
# /usr/local/lib/python3.11/dist-packages/torch/utils/_config_module.py:321: UserWarning: Skipping serialization of skipfiles_inline_module_allowlist value {}
#   warnings.warn(
# I0227 02:18:00.871000 4136 torch/_inductor/debug.py:520] [2/0] Writing debug ir to  /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__0_forward_1.0/ir_pre_fusion.txt
# I0227 02:18:00.880000 4136 torch/_inductor/memory.py:599] [2/0] Reordering for peak memory -- 1 nodes
# I0227 02:18:00.883000 4136 torch/_inductor/memory.py:627] [2/0] Baseline peak memory: 787200
# I0227 02:18:00.884000 4136 torch/_inductor/memory.py:645] [2/0] topological_sort_lpmf peak memory: 787200
# I0227 02:18:00.887000 4136 torch/_inductor/memory.py:645] [2/0] topological_sort_bfs peak memory: 787200
# I0227 02:18:00.888000 4136 torch/_inductor/memory.py:645] [2/0] topological_sort_dfs peak memory: 787200
# I0227 02:18:00.889000 4136 torch/_inductor/debug.py:520] [2/0] Writing debug ir to  /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__0_forward_1.0/ir_post_fusion.txt
# I0227 02:18:00.913000 4136 torch/fx/experimental/symbolic_shapes.py:6104] [2/0] eval s0 < 524288 [guard added] (_inductor/codegen/simd.py:1227 in can_use_32bit_indexing), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_GUARD_ADDED="s0 < 524288"
# I0227 02:18:06.020000 4136 torch/_inductor/compile_fx.py:768] [2/0] Step 3: torchinductor done compiling FORWARDS graph 0
# W0227 02:18:06.021000 4136 torch/_inductor/debug.py:434] [2/0] model__0_forward_1 debug trace: /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__0_forward_1.0
# I0227 02:18:06.028000 4136 torch/_inductor/compile_fx.py:808] [2/0] Step 3: torchinductor compiling BACKWARDS graph 0
# /usr/local/lib/python3.11/dist-packages/torch/utils/_config_module.py:321: UserWarning: Skipping serialization of skipfiles_inline_module_allowlist value {}
#   warnings.warn(
# I0227 02:18:06.096000 4136 torch/_inductor/debug.py:520] [2/0] Writing debug ir to  /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__0_backward_2.1/ir_pre_fusion.txt
# I0227 02:18:06.104000 4136 torch/_inductor/memory.py:599] [2/0] Reordering for peak memory -- 1 nodes
# I0227 02:18:06.106000 4136 torch/_inductor/memory.py:627] [2/0] Baseline peak memory: 1573632
# I0227 02:18:06.108000 4136 torch/_inductor/memory.py:645] [2/0] topological_sort_lpmf peak memory: 1573632
# I0227 02:18:06.110000 4136 torch/_inductor/memory.py:645] [2/0] topological_sort_bfs peak memory: 1573632
# I0227 02:18:06.111000 4136 torch/_inductor/memory.py:645] [2/0] topological_sort_dfs peak memory: 1573632
# I0227 02:18:06.112000 4136 torch/_inductor/debug.py:520] [2/0] Writing debug ir to  /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__0_backward_2.1/ir_post_fusion.txt
# I0227 02:18:07.052000 4136 torch/_inductor/compile_fx.py:768] [2/0] Step 3: torchinductor done compiling BACKWARDS graph 0
# W0227 02:18:07.053000 4136 torch/_inductor/debug.py:434] [2/0] model__0_backward_2 debug trace: /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__0_backward_2.1
# I0227 02:18:07.061000 4136 torch/_dynamo/output_graph.py:1427] [2/0] Step 2: done compiler function inductor
# I0227 02:18:07.067000 4136 torch/fx/experimental/symbolic_shapes.py:4433] [2/0] produce_guards
# I0227 02:18:07.075000 4136 torch/_dynamo/pgo.py:634] [2/0] put_code_state: no cache key, skipping
# I0227 02:18:07.389000 4136 torch/_dynamo/symbolic_convert.py:2800] [3/0] Step 1: torchdynamo start tracing compiled_llama_mlp <ipython-input-8-f094db8e4c94>:72
# I0227 02:18:07.391000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [3/0] create_env
# I0227 02:18:07.446000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [3/0] create_symbol s0 = 96 for L['x'].size()[1] [2, int_oo] if x.dtype in [torch.float32, torch.bfloat16]:  # bitsandbytes/nn/modules.py:437 in set_compute_type (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:07.447000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [3/0] create_symbol s1 = 4096 for L['x'].size()[2] [2, int_oo] if x.dtype in [torch.float32, torch.bfloat16]:  # bitsandbytes/nn/modules.py:437 in set_compute_type (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks] Graph break in user code at /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:484
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks] Reason: Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks] User code traceback:
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "<ipython-input-8-f094db8e4c94>", line 75, in compiled_llama_mlp
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return OriginalMLPForward(self, x)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 190, in forward
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py", line 496, in forward
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     result = self.base_layer(x, *args, **kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 484, in forward
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks] Traceback (most recent call last):
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2418, in CALL
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self._call(inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2412, in _call
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 349, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 125, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 973, in inline_user_function_return
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3127, in inline_call
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3255, in inline_call_
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     tracer.run()
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1120, in run
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     while self.step():
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]           ^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1032, in step
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2418, in CALL
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self._call(inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2412, in _call
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 170, in realize_and_forward
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 913, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 349, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 125, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 973, in inline_user_function_return
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3127, in inline_call
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3255, in inline_call_
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     tracer.run()
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1120, in run
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     while self.step():
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]           ^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1032, in step
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1816, in CALL_FUNCTION_EX
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.call_function(fn, argsvars.items, kwargsvars)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 170, in realize_and_forward
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 913, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 349, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 125, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 973, in inline_user_function_return
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3127, in inline_call
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3255, in inline_call_
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     tracer.run()
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1120, in run
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     while self.step():
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]           ^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1032, in step
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2418, in CALL
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self._call(inst)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2412, in _call
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1022, in call_function
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/user_defined.py", line 825, in call_method
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     return super().call_method(tx, name, args, kwargs)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/base.py", line 424, in call_method
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     unimplemented(f"call_method {self} {name} {args} {kwargs}")
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py", line 313, in unimplemented
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks]     raise Unsupported(msg, case_name=case_name)
# V0227 02:18:07.460000 4136 torch/_dynamo/symbolic_convert.py:415] [3/0] [__graph_breaks] torch._dynamo.exc.Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# I0227 02:18:07.465000 4136 torch/_dynamo/convert_frame.py:744] [3/0] Restarting analysis due to _dynamo/symbolic_convert.py:159 in fail_and_restart_analysis
# I0227 02:18:07.466000 4136 torch/_dynamo/symbolic_convert.py:2800] [3/0_1] Step 1: torchdynamo start tracing compiled_llama_mlp <ipython-input-8-f094db8e4c94>:72
# I0227 02:18:07.467000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [3/0_1] create_env
# I0227 02:18:07.471000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [3/0_1] create_symbol s0 = 96 for L['x'].size()[1] [2, int_oo] return OriginalMLPForward(self, x)  # <ipython-input-8-f094db8e4c94>:75 in compiled_llama_mlp (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:07.472000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [3/0_1] create_symbol s1 = 4096 for L['x'].size()[2] [2, int_oo] return OriginalMLPForward(self, x)  # <ipython-input-8-f094db8e4c94>:75 in compiled_llama_mlp (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:07.484000 4136 torch/fx/experimental/symbolic_shapes.py:4433] [3/0_1] produce_guards
# I0227 02:18:07.490000 4136 torch/_dynamo/pgo.py:634] [3/0_1] put_code_state: no cache key, skipping
# I0227 02:18:07.493000 4136 torch/_dynamo/symbolic_convert.py:2800] [4/0] Step 1: torchdynamo start tracing forward /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py:189
# I0227 02:18:07.494000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [4/0] create_env
# I0227 02:18:07.526000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [4/0] create_symbol s0 = 96 for L['x'].size()[1] [2, int_oo] if x.dtype in [torch.float32, torch.bfloat16]:  # bitsandbytes/nn/modules.py:437 in set_compute_type (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:07.527000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [4/0] create_symbol s1 = 4096 for L['x'].size()[2] [2, int_oo] if x.dtype in [torch.float32, torch.bfloat16]:  # bitsandbytes/nn/modules.py:437 in set_compute_type (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks] Graph break in user code at /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:484
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks] Reason: Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks] User code traceback:
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 190, in forward
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py", line 496, in forward
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     result = self.base_layer(x, *args, **kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 484, in forward
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks] Traceback (most recent call last):
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2418, in CALL
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     self._call(inst)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2412, in _call
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 170, in realize_and_forward
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 913, in call_function
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 349, in call_function
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 125, in call_function
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 973, in inline_user_function_return
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3127, in inline_call
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3255, in inline_call_
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     tracer.run()
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1120, in run
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     while self.step():
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]           ^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1032, in step
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1816, in CALL_FUNCTION_EX
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     self.call_function(fn, argsvars.items, kwargsvars)
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:07.541000 4136 torch/_dynamo/symbolic_convert.py:415] [4/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# W0227 02:18:16.842000 4136 torch/_inductor/debug.py:434] [33/1] model__14_forward_23 debug trace: /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__14_forward_23.18
# I0227 02:18:16.848000 4136 torch/_inductor/compile_fx.py:808] [33/1] Step 3: torchinductor compiling BACKWARDS graph 14
# /usr/local/lib/python3.11/dist-packages/torch/utils/_config_module.py:321: UserWarning: Skipping serialization of skipfiles_inline_module_allowlist value {}
#   warnings.warn(
# I0227 02:18:16.890000 4136 torch/_inductor/debug.py:520] [33/1] Writing debug ir to  /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__14_backward_24.19/ir_pre_fusion.txt
# I0227 02:18:16.895000 4136 torch/_inductor/memory.py:599] [33/1] Reordering for peak memory -- 7 nodes
# I0227 02:18:16.898000 4136 torch/_inductor/memory.py:627] [33/1] Baseline peak memory: 5537792
# I0227 02:18:16.900000 4136 torch/_inductor/memory.py:645] [33/1] topological_sort_lpmf peak memory: 5543936
# I0227 02:18:16.902000 4136 torch/_inductor/memory.py:645] [33/1] topological_sort_bfs peak memory: 5537792
# I0227 02:18:16.904000 4136 torch/_inductor/memory.py:645] [33/1] topological_sort_dfs peak memory: 5543936
# I0227 02:18:16.905000 4136 torch/_inductor/debug.py:520] [33/1] Writing debug ir to  /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__14_backward_24.19/ir_post_fusion.txt
# I0227 02:18:17.586000 4136 torch/_inductor/compile_fx.py:768] [33/1] Step 3: torchinductor done compiling BACKWARDS graph 14
# W0227 02:18:17.587000 4136 torch/_inductor/debug.py:434] [33/1] model__14_backward_24 debug trace: /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__14_backward_24.19
# I0227 02:18:17.595000 4136 torch/_dynamo/output_graph.py:1427] [33/1] Step 2: done compiler function inductor
# I0227 02:18:17.603000 4136 torch/fx/experimental/symbolic_shapes.py:4433] [33/1] produce_guards
# I0227 02:18:17.623000 4136 torch/_dynamo/pgo.py:634] [33/1] put_code_state: no cache key, skipping
# I0227 02:18:17.905000 4136 torch/_dynamo/symbolic_convert.py:2800] [36/0] Step 1: torchdynamo start tracing torch_dynamo_resume_in_forward_at_190 /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py:190
# I0227 02:18:17.906000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [36/0] create_env
# I0227 02:18:17.910000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [36/0] create_symbol s0 = 96 for L['___stack0'].size()[1] [2, int_oo] down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))  # transformers/models/llama/modeling_llama.py:190 in torch_dynamo_resume_in_forward_at_190 (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:17.911000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [36/0] create_symbol s1 = 4096 for L['___stack0'].size()[2] [2, int_oo] down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))  # transformers/models/llama/modeling_llama.py:190 in torch_dynamo_resume_in_forward_at_190 (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:17.917000 4136 torch/_dynamo/pgo.py:634] [36/0] put_code_state: no cache key, skipping
# V0227 02:18:19.554000 4136 torch/_dynamo/guards.py:2649] [6/1] [__recompiles_verbose] Recompiling function forward in /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:467
# V0227 02:18:19.554000 4136 torch/_dynamo/guards.py:2649] [6/1] [__recompiles_verbose]     triggered by the following guard failure(s):
# V0227 02:18:19.554000 4136 torch/_dynamo/guards.py:2649] [6/1] [__recompiles_verbose]     guard 0 failures:
# V0227 02:18:19.554000 4136 torch/_dynamo/guards.py:2649] [6/1] [__recompiles_verbose]     - 6/0: ___check_obj_id(L['self'].compute_type_is_set, 9619232)
# I0227 02:18:19.556000 4136 torch/_dynamo/symbolic_convert.py:2800] [6/1] Step 1: torchdynamo start tracing forward /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:467
# I0227 02:18:19.557000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [6/1] create_env
# I0227 02:18:19.567000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [6/1] create_symbol s0 = 97 for L['x'].size()[1] [2, int_oo] inp_dtype = x.dtype  # bitsandbytes/nn/modules.py:478 in forward (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:19.568000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [6/1] create_symbol s1 = 4096 for L['x'].size()[2] [2, int_oo] inp_dtype = x.dtype  # bitsandbytes/nn/modules.py:478 in forward (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks] Graph break in user code at /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:484
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks] Reason: Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks] User code traceback:
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 484, in forward
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks] Traceback (most recent call last):
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 640, in wrapper
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     return inner_fn(self, inst)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2418, in CALL
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     self._call(inst)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2412, in _call
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 967, in call_function
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1022, in call_function
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/user_defined.py", line 825, in call_method
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     return super().call_method(tx, name, args, kwargs)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/base.py", line 424, in call_method
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     unimplemented(f"call_method {self} {name} {args} {kwargs}")
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py", line 313, in unimplemented
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks]     raise Unsupported(msg, case_name=case_name)
# V0227 02:18:19.575000 4136 torch/_dynamo/symbolic_convert.py:415] [6/1] [__graph_breaks] torch._dynamo.exc.Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# I0227 02:18:19.577000 4136 torch/_dynamo/convert_frame.py:744] [6/1] Restarting analysis due to _dynamo/symbolic_convert.py:159 in fail_and_restart_analysis
# I0227 02:18:19.579000 4136 torch/_dynamo/symbolic_convert.py:2800] [6/1_1] Step 1: torchdynamo start tracing forward /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:467
# I0227 02:18:19.580000 4136 torch/fx/experimental/symbolic_shapes.py:3125] [6/1_1] create_env
# I0227 02:18:19.586000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [6/1_1] create_symbol s0 = 97 for L['x'].size()[1] [2, int_oo] inp_dtype = x.dtype  # bitsandbytes/nn/modules.py:478 in forward (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s0" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:19.587000 4136 torch/fx/experimental/symbolic_shapes.py:4324] [6/1_1] create_symbol s1 = 4096 for L['x'].size()[2] [2, int_oo] inp_dtype = x.dtype  # bitsandbytes/nn/modules.py:478 in forward (_dynamo/variables/builder.py:2796 in <lambda>), for more info run with TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="s1" or to suppress this message run with TORCHDYNAMO_EXTENDED_ADVICE="0"
# I0227 02:18:19.597000 4136 torch/_dynamo/output_graph.py:1422] [6/1_1] Step 2: calling compiler function inductor
# W0227 02:18:19.617000 4136 torch/_inductor/debug.py:434] [6/1_1] model__15_inference_25 debug trace: /content/torch_compile_debug/run_2025_02_27_02_18_00_741261-pid_4136/torchinductor/model__15_inference_25.20
# I0227 02:18:19.623000 4136 torch/_dynamo/output_graph.py:1427] [6/1_1] Step 2: done compiler function inductor
# I0227 02:18:19.629000 4136 torch/fx/experimental/symbolic_shapes.py:4433] [6/1_1] produce_guards
# I0227 02:18:19.639000 4136 torch/_dynamo/pgo.py:634] [6/1_1] put_code_state: no cache key, skipping
#     <div>
#
#       <progress value='630' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [630/630 12:35, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.760900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.627000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.772200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.690400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.683000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.391700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.640800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.277600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.471200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.236500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.595600</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.169200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.483600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.215000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.211600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.308200</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.524800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.489600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.354400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.334100</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.417300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.299700</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.266400</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.173900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.222600</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.489000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.139300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.359200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.343000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.239400</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.488400</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.232000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.079800</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.351900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.158400</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.182400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.066800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.352200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>1.119100</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.311700</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.095900</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.285200</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.363000</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.088900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.346500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.157700</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.103600</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.185700</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>1.125000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.196300</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.103100</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.108200</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.859400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>1.138400</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.980100</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>1.130300</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>1.130200</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>1.030100</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.196500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.955500</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>1.230300</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>1.195500</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.991100</td>
#     </tr>
#   </tbody>
# </table><p>
# Done partial compile QLoRA training!
# Final Score: 9
#
# How to delete a Jupyter notebook from your GitHub repo:
# 1. Go to the file in your GitHub repository.
# 2. Click the trashcan icon ('Delete this file').
# 3. Add a commit message and click 'Commit changes'.
# Alternatively, use 'git rm <filename>' and then 'git commit' + 'git push' if using Git locally.
